# %% [markdown]
# #Linear Regression

# %% [markdown]
# #House_price

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file = pd.read_csv('/content/drive/MyDrive/Python from Shiv sir/House_price data.txt')
file
# Out:
#      area   bedrooms  mainroad       furnishing   price(in cr)
# 0    7420          4       yes        furnished         1.3300
# 1    8960          4        no        furnished         1.2250
# 2    9960          3        no   semi-furnished         1.2250
# 3    7500          4       yes        furnished         1.2215
# 4    7420          4       yes        furnished         1.1410
# 5    7500          3       yes   semi-furnished         1.0850
# 6    8580          4        no   semi-furnished         1.0150
# 7   16200          5       yes      unfurnished         1.0150
# 8    8100          4       yes        furnished         0.9870
# 9    5750          3       yes      unfurnished         0.9800
# 10  13200          3       yes        furnished         0.9800
# 11   6550          4       yes   semi-furnished         0.9310
# 12   3500          4       yes        furnished         0.9240
# 13   6000          4       yes   semi-furnished         0.9100
# ...

# %%
file.columns
# Out:
# Index(['area', ' bedrooms', ' mainroad', ' furnishing', ' price(in cr)'], dtype='object')

# %%
# cat_col=[ " mainroad", " furnishing"]
cat_col=[" mainroad", " furnishing"]
file[cat_col]
new_df=pd.get_dummies(file[cat_col], dtype = "int")
new_df
# Out:
#      mainroad_ no   mainroad_ yes   furnishing_ furnished  \
# 0               0               1                       1
# 1               1               0                       1
# 2               1               0                       0
# 3               0               1                       1
# 4               0               1                       1
# 5               0               1                       0
# 6               1               0                       0
# 7               0               1                       0
# 8               0               1                       1
# 9               0               1                       0
# 10              0               1                       1
# 11              0               1                       0
# 12              0               1                       1
# 13              0               1                       0
# 14              0               1                       0
# ...

# %%
file.drop(file[cat_col],axis=1,inplace=True)
file
# Out:
#      area   bedrooms   price(in cr)
# 0    7420          4         1.3300
# 1    8960          4         1.2250
# 2    9960          3         1.2250
# 3    7500          4         1.2215
# 4    7420          4         1.1410
# 5    7500          3         1.0850
# 6    8580          4         1.0150
# 7   16200          5         1.0150
# 8    8100          4         0.9870
# 9    5750          3         0.9800
# 10  13200          3         0.9800
# 11   6550          4         0.9310
# 12   3500          4         0.9240
# 13   6000          4         0.9100
# 14   6600          4         0.9100
# 15   4600          3         0.8890
# 16   6420          3         0.8855
# 17   7155          3         0.8680
# 18   8050          3         0.8645

# %%
new_file=pd.concat([new_df, file],axis=1)
new_file
# Out:
#      mainroad_ no   mainroad_ yes   furnishing_ furnished  \
# 0               0               1                       1
# 1               1               0                       1
# 2               1               0                       0
# 3               0               1                       1
# 4               0               1                       1
# 5               0               1                       0
# 6               1               0                       0
# 7               0               1                       0
# 8               0               1                       1
# 9               0               1                       0
# 10              0               1                       1
# 11              0               1                       0
# 12              0               1                       1
# 13              0               1                       0
# 14              0               1                       0
# ...

# %%
X = new_file.iloc[:,:7]
X
# Out:
#      mainroad_ no   mainroad_ yes   furnishing_ furnished  \
# 0               0               1                       1
# 1               1               0                       1
# 2               1               0                       0
# 3               0               1                       1
# 4               0               1                       1
# 5               0               1                       0
# 6               1               0                       0
# 7               0               1                       0
# 8               0               1                       1
# 9               0               1                       0
# 10              0               1                       1
# 11              0               1                       0
# 12              0               1                       1
# 13              0               1                       0
# 14              0               1                       0
# ...

# %%
Y = new_file.iloc[:, -1]
Y
# Out:
# 0     1.3300
# 1     1.2250
# 2     1.2250
# 3     1.2215
# 4     1.1410
# 5     1.0850
# 6     1.0150
# 7     1.0150
# 8     0.9870
# 9     0.9800
# 10    0.9800
# 11    0.9310
# 12    0.9240
# 13    0.9100
# 14    0.9100
# 15    0.8890
# 16    0.8855
# 17    0.8680
# 18    0.8645
# Name:  price(in cr), dtype: float64

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(X,Y)
# Out:
# LinearRegression()

# %%
reg.predict([[0,1,1,0,0,7600,4]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.06067367])

# %% [markdown]
# #Gradio

# %%
# !pip install gradio
import gradio as gr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 48.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 7.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.2/318.2 kB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 50.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 5.2 MB/s eta 0:00:00
# ...

# %%
new_file.columns
# Out:
# Index([' mainroad_ no', ' mainroad_ yes', ' furnishing_ furnished',
#        ' furnishing_ semi-furnished', ' furnishing_ unfurnished', 'area',
#        ' bedrooms', ' price(in cr)'],
#       dtype='object')

# %%
# Function to predict salary

def predict_house_price( mainroad_ no, mainroad_ yes, furnishing_ furnished, furnishing_ semi-furnished, furnishing_ unfurnished,area, bedrooms):
    # Reshape inputs to match model's expected input shape
    mainroad_ no=int(" mainroad_ no")
    mainroad_ yes=int(" mainroad_ yes"))"
    furnishing_ furnished=int(" furnishing_ furnished")
    furnishing_ semi-furnished=int(" furnishing_ semi-furnished")
    furnishing_ unfurnished=int(" furnishing_ unfurnished")
    area= int("area")
    bedrooms= int(" bedrooms")


    inputs = np.array([[experience, test_score, interview_score]]).reshape(1, -1)
    prediction = regressor.predict(inputs)

    return (prediction[0]).round(2)

# %%
# Create interface
# Interface
textbox1 = gr.Textbox(label="Enter Experience: ", type="text")
textbox2 = gr.Textbox(label="Enter Test_score: ", type="text")
textbox3 = gr.Textbox(label="Enter interview_score: ", type="text")
output = gr.Textbox(label="Predicted Salary")
interface = gr.Interface(fn=predict_salary, inputs=[textbox1,textbox2,textbox3], outputs=output, title="Salary Prediction Model")
interface.launch(share=True)

# %% [markdown]
# #Gradio

# %% [markdown]
# #House_price with Binary dataset

# %%
import pandas as pd

# %%
file = pd.read_csv("/content/drive/MyDrive/Python from Shiv sir/house_price data binary.txt")
file
# Out:
#      area   bedrooms   mainroad   furnishing   price(in cr)
# 0    7420          4          1            1         1.3300
# 1    8960          4          1            1         1.2250
# 2    9960          3          1            0         1.2250
# 3    7500          4          1            1         1.2215
# 4    7420          4          1            1         1.1410
# 5    7500          3          1            0         1.0850
# 6    8580          4          1            0         1.0150
# 7   16200          5          1           -1         1.0150
# 8    8100          4          1            1         0.9870
# 9    5750          3          1           -1         0.9800
# 10  13200          3          1            1         0.9800
# 11   6550          4          1            0         0.9310
# 12   3500          4          1            1         0.9240
# 13   6000          4          1            0         0.9100
# 14   6600          4          1           -1         0.9100
# ...

# %%
X = file.iloc[:,:4]
X
# Out:
#      area   bedrooms   mainroad   furnishing
# 0    7420          4          1            1
# 1    8960          4          1            1
# 2    9960          3          1            0
# 3    7500          4          1            1
# 4    7420          4          1            1
# 5    7500          3          1            0
# 6    8580          4          1            0
# 7   16200          5          1           -1
# 8    8100          4          1            1
# 9    5750          3          1           -1
# 10  13200          3          1            1
# 11   6550          4          1            0
# 12   3500          4          1            1
# 13   6000          4          1            0
# 14   6600          4          1           -1
# 15   4600          3          1            1
# 16   6420          3          1            0
# 17   7155          3          1           -1
# 18   8050          3          1            1

# %%
Y= file.iloc[:, -1]
Y
# Out:
# 0     1.3300
# 1     1.2250
# 2     1.2250
# 3     1.2215
# 4     1.1410
# 5     1.0850
# 6     1.0150
# 7     1.0150
# 8     0.9870
# 9     0.9800
# 10    0.9800
# 11    0.9310
# 12    0.9240
# 13    0.9100
# 14    0.9100
# 15    0.8890
# 16    0.8855
# 17    0.8680
# 18    0.8645
# Name:  price(in cr), dtype: float64

# %%
from sklearn.linear_model  import LinearRegression
House_data = LinearRegression()

# %%
House_data.fit(X,Y)
# Out:
# LinearRegression()

# %%
d1 = float( House_data.predict([[7600, 5, 0, -1]]))
d1
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# <ipython-input-76-01ca22939f31>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   d1 = float( House_data.predict([[7600, 5, 0, -1]]))
# 0.9948780511776382

# %%
d2 = float(House_data.predict([[7600, 5, 1, -1]]))
d2
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# <ipython-input-78-b64cfc66ef0c>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   d2 = float(House_data.predict([[7600, 5, 1, -1]]))
# 0.9948780511776382

# %%
d3 = float(House_data.predict([[7600, 3, 0, -1]]))
d3
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# <ipython-input-79-0a4d852de4d0>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   d3 = float(House_data.predict([[7600, 3, 0, -1]]))
# 0.9056614640479531

# %%
d4 = float(House_data.predict([[7600, 5, 0, 1]]))
d4
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# <ipython-input-80-08085e4820c3>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   d4 = float(House_data.predict([[7600, 5, 0, 1]]))
# 1.1267433016332307

# %%
data = [d1,d2,d3,d4]
data
# Out:
# [0.9948780511776382,
#  0.9948780511776382,
#  0.9056614640479531,
#  1.1267433016332307]

# %%
plt.hist(data, color = "blue", label = "predictions", bins = 10)
# Out:
# (array([1., 0., 0., 0., 2., 0., 0., 0., 0., 1.]),
#  array([0.90566146, 0.92776965, 0.94987783, 0.97198602, 0.9940942 ,
#         1.01620238, 1.03831057, 1.06041875, 1.08252693, 1.10463512,
#         1.1267433 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data, color = "blue", label = "predictions", bins = 3)
# Out:
# (array([1., 2., 1.]),
#  array([0.90566146, 0.97935541, 1.05304936, 1.1267433 ]),
#  <BarContainer object of 3 artists>)
